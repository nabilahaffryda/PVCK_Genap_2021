# %% [markdown]
# <a href="https://colab.research.google.com/github/nabilahaffryda/PVCK_Genap_2021/blob/main/Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

#accessing my google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
import math

print(' Mengubah tingkat kecerahan citra') 
print('---------------------------------') 
try:
  brightness = int(input('Masukkan nilai kecerahan: ')) 
except ValueError:
  print('Error, not a number')

original = cv.imread('/content/drive/MyDrive/PVCK/Images/sehun.jpg') 
brightness_image = np.zeros(original.shape, original.dtype)

#akses per piksel 
for y in range (original.shape[0]): 
  for x in range (original.shape[1]): 
    for c in range (original.shape[2]):
      brightness_image[y,x,c] = np.clip(original[y,x,c] + brightness, 0, 255)

#cara simple tanpa for loop 
#brightness_image = cv.convertScaleAbs (original, beta-brightness)

final_frame = cv.hconcat((original, brightness_image)) 
cv2_imshow(final_frame)
# Out:
#  Mengubah tingkat kecerahan citra
# ---------------------------------
# Masukkan nilai kecerahan: 50
# <PIL.Image.Image image mode=RGB size=1188x593 at 0x7F5430BA6210>

# %%
#Task No 1

#membuat figure
fig = plt.figure(figsize=(10, 7)) 
# mengatur nilai ke variabel baris dan kolom
rows = 1
columns = 2

print('Mengubah tingkat kecerahan citra')
print('--------------------------------')
try:
  brightness = int(input('Masukkan nilai kecerahan:  (-255 - 255) : '))
  contrass = float(input('Masukkan contrast  (1.0 - 3.0): '))
except ValueError:
  print('Error, not a number')

readoriginal = cv.imread('/content/drive/MyDrive/PVCK/Images/sehun.jpg')
original = cv.cvtColor(readoriginal, cv.COLOR_BGR2RGB)
brightness_image = cv.cvtColor(readoriginal, cv.COLOR_BGR2RGB)

#akses per pixel
for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      brightness_image[y,x,c] = np.clip(contrass * original[y,x,c] + brightness, 0,255)

# Menambahkan subplot di posisi ke-1
fig.add_subplot(rows, columns, 1) 
plt.axis('off') 
plt.imshow(original) 
  
# Menambahkan subplot di posisi ke-2
fig.add_subplot(rows, columns, 2) 
plt.axis('off') 
plt.imshow(brightness_image)
# Out:
# Mengubah tingkat kecerahan citra
# --------------------------------
# Masukkan nilai kecerahan:  (-255 - 255) : 60
# Masukkan contrast  (1.0 - 3.0): 1.5

# %%
#Task no 2

#membuat figure
fig = plt.figure(figsize=(10, 7)) 
# mengatur nilai ke variabel baris dan kolom
rows = 1
columns = 2

print('Mengubah tingkat kecerahan citra dengan Transformasi Log')
print('--------------------------------------------------------')
try:
  brightness = int(input('Masukkan nilai kecerahan: '))
except ValueError:
  print('Error, not a number')

readoriginal = cv.imread('/content/drive/MyDrive/PVCK/Images/sehun.jpg')
original = cv.cvtColor(readoriginal, cv.COLOR_BGR2RGB)
brightness_image = cv.cvtColor(readoriginal, cv.COLOR_BGR2RGB)

#akses per pixel
for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      brightness_image[y,x,c] = np.clip(brightness * math.log(1 + original[y,x,c]), 0,255)

# Menambahkan subplot di posisi ke-1
fig.add_subplot(rows, columns, 1) 
plt.axis('off') 
plt.imshow(original) 
  
# Menambahkan subplot di posisi ke-2
fig.add_subplot(rows, columns, 2) 
plt.axis('off') 
plt.imshow(brightness_image)
# Out:
# Mengubah tingkat kecerahan citra dengan Transformasi Log
# --------------------------------------------------------
# Masukkan nilai kecerahan: 40

# %%
#Task no 3 (a)

#membuat figure
fig = plt.figure(figsize=(10, 7)) 
# mengatur nilai ke variabel baris dan kolom
rows = 1
columns = 2

grayscale_image = cv.cvtColor(readoriginal, cv.COLOR_BGR2RGB)
grayscale_image[:] = original.mean(axis=-1, keepdims=1)

# Menambahkan subplot di posisi ke-1
fig.add_subplot(rows, columns, 1) 
plt.axis('off') 
plt.imshow(original) 
  
# Menambahkan subplot di posisi ke-2
fig.add_subplot(rows, columns, 2) 
plt.axis('off') 
plt.imshow(grayscale_image)

# %%
#Task no 3 (b)

#membuat figure
fig = plt.figure(figsize=(10, 7)) 
# mengatur nilai ke variabel baris dan kolom
rows = 1
columns = 2

grayscale_image_light = cv.cvtColor(readoriginal, cv.COLOR_BGR2RGB)
grayscale_image_light[:] = np.max(original, axis=-1, keepdims=1) / 2 + np.min(original, axis=-1, keepdims=1) / 2

# Menambahkan subplot di posisi ke-1
fig.add_subplot(rows, columns, 1) 
plt.axis('off') 
plt.imshow(original) 
  
# Menambahkan subplot di posisi ke-2
fig.add_subplot(rows, columns, 2) 
plt.axis('off') 
plt.imshow(grayscale_image_light)

# %%
#Task no 3 (c)

#membuat figure
fig = plt.figure(figsize=(10, 7)) 
# mengatur nilai ke variabel baris dan kolom
rows = 1
columns = 2

grayscale_image = cv.cvtColor(readoriginal, cv.COLOR_BGR2RGB)
W = [0.21, 0.72, 0.07]
W_mean = np.tensordot(original, W, axes=((-1, -1)))[..., None]
grayscale_image[:] = W_mean.astype(original.dtype)

# Menambahkan subplot di posisi ke-1
fig.add_subplot(rows, columns, 1) 
plt.axis('off') 
plt.imshow(original) 
  
# Menambahkan subplot di posisi ke-2
fig.add_subplot(rows, columns, 2) 
plt.axis('off') 
plt.imshow(grayscale_image)

# %%
#Task no 4

#membuat figure
fig = plt.figure(figsize=(10, 7)) 
# mengatur nilai ke variabel baris dan kolom
rows = 1
columns = 2

grayscale_image = cv.cvtColor(readoriginal, cv.COLOR_BGR2RGB)

for i in range(original.shape[0]):
    for j in range(original.shape[1]):
        if (original[i, j, 0] < 210 and original[i, j, 1] < 160):
            grayscale_image[i, j] = np.mean(original[i, j])

# Menambahkan subplot di posisi ke-1
fig.add_subplot(rows, columns, 1) 
plt.axis('off') 
plt.imshow(original) 
  
# Menambahkan subplot di posisi ke-2
fig.add_subplot(rows, columns, 2) 
plt.axis('off') 
plt.imshow(grayscale_image)
